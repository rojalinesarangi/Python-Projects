# %%
import random
import hangman_stages
import Word_list

lives=6
chosen_word=random.choice(Word_list.Words).lower()
print(chosen_word)
display=[]
for i in range(len(chosen_word)):
    display +='_'
print(display)
game_over=False
while not game_over:
    guessed_letter=input('Guess a letter:').lower()
    for position in range(len(chosen_word)):
        letter=chosen_word[position]
        if letter==guessed_letter:
            display[position]=guessed_letter
    print(display)        
    if guessed_letter not in chosen_word:
        lives -= 1
        if lives == 0:
            game_over=True
            print('you lose!!')
    if '_' not in display:
        game_over=True
        print('you win!!')
    print(hangman_stages.stages[lives])
# Out:
# passionfruit
# ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Guess a letter:P
# ['p', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
#
#     +---+
#     |   |
#         |
#         |
#         |
#         |
#
# Guess a letter:s
# ['p', '_', 's', 's', '_', '_', '_', '_', '_', '_', '_', '_']
#
#     +---+
#     |   |
#         |
#         |
#         |
#         |
#
# Guess a letter:i
# ['p', '_', 's', 's', 'i', '_', '_', '_', '_', '_', 'i', '_']
#
#     +---+
#     |   |
#         |
#         |
#         |
#         |
#
# Guess a letter:t
# ['p', '_', 's', 's', 'i', '_', '_', '_', '_', '_', 'i', 't']
#
#     +---+
#     |   |
#         |
#         |
#         |
#         |
#
# Guess a letter:a
# ['p', 'a', 's', 's', 'i', '_', '_', '_', '_', '_', 'i', 't']
#
#     +---+
#     |   |
#         |
#         |
#         |
#         |
#
# Guess a letter:b
# ['p', 'a', 's', 's', 'i', '_', '_', '_', '_', '_', 'i', 't']
#
#     +---+
#     |   |
#     O   |
#         |
#         |
#         |
# ==========
#
# Guess a letter:n
# ['p', 'a', 's', 's', 'i', '_', 'n', '_', '_', '_', 'i', 't']
#
#     +---+
#     |   |
#     O   |
#         |
#         |
#         |
# ==========
#
# Guess a letter:u
# ['p', 'a', 's', 's', 'i', '_', 'n', '_', '_', 'u', 'i', 't']
#
#     +---+
#     |   |
#     O   |
#         |
#         |
#         |
# ==========
#
# Guess a letter:i
# ['p', 'a', 's', 's', 'i', '_', 'n', '_', '_', 'u', 'i', 't']
#
#     +---+
#     |   |
#     O   |
#         |
#         |
#         |
# ==========
#
# Guess a letter:f
# ['p', 'a', 's', 's', 'i', '_', 'n', 'f', '_', 'u', 'i', 't']
#
#     +---+
#     |   |
#     O   |
#         |
#         |
#         |
# ==========
#
# Guess a letter:r
# ['p', 'a', 's', 's', 'i', '_', 'n', 'f', 'r', 'u', 'i', 't']
#
#     +---+
#     |   |
#     O   |
#         |
#         |
#         |
# ==========
#
# Guess a letter:o
# ['p', 'a', 's', 's', 'i', 'o', 'n', 'f', 'r', 'u', 'i', 't']
# you win!!
#
#     +---+
#     |   |
#     O   |
#         |
#         |
#         |
# ==========
